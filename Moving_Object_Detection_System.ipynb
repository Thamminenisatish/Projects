# %% [markdown]
# <a href="https://colab.research.google.com/github/Thamminenisatish/Projects/blob/main/Moving_Object_Detection_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Project Name: Moving Object Detection System (Computer Vision)
# ##Project done by: Thammineni Satish

# %%
pip install ultralytics opencv-python-headless

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load YOLOv8 model (nano version for speed, you can use yolov8n, yolov8s, etc.)
model = YOLO("yolov8n.pt")

# Load image from Google Drive
image_path = "/content/drive/MyDrive/WhatsApp Image 2024-12-13 at 11.31.49_26f4e9c1.jpg"
image = cv2.imread(image_path)

# Run object detection
results = model(image_path)

# Visualize detected objects
annotated_image = results[0].plot()

# Display the annotated image
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 160MB/s]
# image 1/1 /content/drive/MyDrive/WhatsApp Image 2024-12-13 at 11.31.49_26f4e9c1.jpg: 480x640 1 orange, 1 clock, 413.6ms
# Speed: 6.4ms preprocess, 413.6ms inference, 40.2ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ##Object detection in video

# %%
from ultralytics import YOLO
import cv2

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Define video input and output paths
video_path = "/content/drive/MyDrive/VID20241217111033.mp4"
output_path = "/content/drive/MyDrive/detected_video.mp4"

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get video details
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define video writer to save output
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Process video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run object detection on the frame
    results = model(frame)

    # Annotate frame with detection results
    annotated_frame = results[0].plot()

    # Write the annotated frame to output video
    out.write(annotated_frame)

# Release resources
cap.release()
out.release()

print(f"Processed video saved at: {output_path}")
# Out:
# 0: 640x384 2 persons, 1 dining table, 163.7ms
# Speed: 4.3ms preprocess, 163.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 dining table, 277.4ms
# Speed: 4.0ms preprocess, 277.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 dining tables, 226.1ms
# Speed: 4.0ms preprocess, 226.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 dining table, 211.9ms
# Speed: 4.1ms preprocess, 211.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 dining table, 259.6ms
# Speed: 4.1ms preprocess, 259.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 dining table, 228.3ms
# Speed: 12.3ms preprocess, 228.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 dining table, 1 teddy bear, 230.7ms
# ...

# %% [markdown]
# ##Please find detected video file at following path
#
# https://drive.google.com/file/d/1ZiwOwgP7sunsiZ6jAc5egDDWIb_Nixj_/view?usp=sharing
